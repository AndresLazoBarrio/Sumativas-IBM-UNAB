# %% [markdown]
# # Data Science Tools and Ecosystem

# %% [markdown]
# ![2-title.png](attachment:2-title.png)

# %% [markdown]
# Introduction:
#
# In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# ![3-intro-2.png](attachment:3-intro-2.png)

# %% [markdown]
# Some of the popular languages that Data Scientists use are:
#
# 1) Python.
#
# 2) R.
#
# 3) SQL.

# %% [markdown]
# ![4-dslanguages-2.png](attachment:4-dslanguages-2.png)

# %% [markdown]
# Some of the commonly used libraries used by Data Scientists include:
#
# 1) Pandas.
#
# 2) NumPy.
#
# 3) Scikit-learn.

# %% [markdown]
# ![5-dslibraries-2.png](attachment:5-dslibraries-2.png)

# %% [markdown]
# | Data Science Tools |
# | -------------|
# | Jupyter |
# | RStudio |
# | Apache Zeppelin |

# %% [markdown]
# ![6-dstools.png](attachment:6-dstools.png)

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# ![Arithmetic%20in%20Python.png](attachment:Arithmetic%20in%20Python.png)

# %%
# This a simple arithmetic expression to mutiply then add integers

(3*4)+5
# Out:
# 17

# %% [markdown]
# ![8-multiplyandaddintegers-2.png](attachment:8-multiplyandaddintegers-2.png)

# %%
# This will convert 200 minutes to hours by diving by 60.

(200)/60
# Out:
# 3.3333333333333335

# %% [markdown]
# ![9-hourstominutes-2.png](attachment:9-hourstominutes-2.png)

# %% [markdown]
# **Objectives:**
#
# * List popular languages for Data Science.
# * List common libraries used by data scientists.
# * Show examples of basic arithmetic operations in Python.

# %% [markdown]
# ## Author
#
# Andrés Lazo Barrio

# %% [markdown]
# ![11-authordetails.png](attachment:11-authordetails.png)
